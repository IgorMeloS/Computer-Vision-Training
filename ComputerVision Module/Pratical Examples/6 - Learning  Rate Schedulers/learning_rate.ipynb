# %% [markdown]
# # Mini VGG architecture on CIFAR10 dataset with Learning Rate Scheduler
#
# In the last example, we've explored the Mini-VGG architecture, based on the VGG family from [Simonyan and Zisserman](https://arxiv.org/pdf/1409.1556.pdf). For this example, we consider the Learning Rate Scheduler, to propose a piecewise function to change the learning rate, every five epochs. In the previous example, we've considered the learn rate decay, where we just can to change the power of the function. The advantage of Learning Rate Scheduler is that, we can think about our function.

# %% [markdown]
# ## Importing Libraries

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from compvis.ann.cnns import MiniVGG # compvis module
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %% [markdown]
# ## Loading and prepocessing the dataset

# %%
((X_train, y_train), (X_test, y_test)) = cifar10.load_data() # defining the training and test set

# %% [markdown]
# **Normalization**

# %%
X_train = X_train.astype("float") / 255.
X_test = X_test.astype("float") / 255. # Normalization [0,1]

# %% [markdown]
# **Label Encoding**

# %%
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %% [markdown]
# **List of targets**

# %%
labelNames = ["airplane", "automobile", "bird", "cat", "deer","dog", "frog",
              "horse", "ship", "truck"]

# %% [markdown]
# ## Building the model
#
# We build the Mini VGG model with the compvis module, using the submodule cnns, we call MiniVGG class. Beyond the model, we also consider the SGD regularization.
#
# **The Mini VGG** considered here is constituted by 4 convolutional layers, two with $32$ and $16$ filters.

# %% [markdown]
# **Step function for the learning rate decay**
#
# The step function considered here is defined as:
#
# $\alpha_{i + 1} = \alpha_{0}F^(1 + i/D ^)$
#
# where $ \alpha_{0}$ is the initial Learning rate, $F$ is a factor to control the decay and $D$ is the step of decay.

# %%
def step_decay(epoch, lr):
    
    init_alpha = 0.01 # initial learning rate
    factor = 0.25
    dropEvery = 5 # step size
    
    if epoch == 1:
        lr = init_alpha
    elif   epoch%5 == 0:
        lr = init_alpha * (factor ** np.floor((1 + epoch) / dropEvery))
    else:
        lr = lr
    return lr

# %% [markdown]
# **Creating the callback and the model**

# %%
callbacks = [LearningRateScheduler(step_decay)]

# %%
opt = SGD(momentum=0.9, nesterov=True) # regularization
model = MiniVGG.build(32, 32, 3, 10) # w, h, depth, classes
model.compile(loss = "categorical_crossentropy",
              optimizer = opt,
              metrics = ["accuracy"]) # Compiling the model

# %% [markdown]
# **Training the model with $40$ epochs with a factor $F = 0.25$ in the step function**.

# %%
H = model.fit(X_train, y_train, validation_data = (X_test, y_test),
              batch_size = 64, epochs = 40, callbacks=callbacks, verbose = 1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 11s 227us/sample - loss: 1.6294 - accuracy: 0.4606 - val_loss: 1.3607 - val_accuracy: 0.5384
# Epoch 2/40
# 50000/50000 [==============================] - 8s 169us/sample - loss: 1.1521 - accuracy: 0.6035 - val_loss: 0.8977 - val_accuracy: 0.6866
# Epoch 3/40
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.9636 - accuracy: 0.6643 - val_loss: 0.8166 - val_accuracy: 0.7183
# Epoch 4/40
# 50000/50000 [==============================] - 8s 170us/sample - loss: 0.8590 - accuracy: 0.7017 - val_loss: 0.7709 - val_accuracy: 0.7287
# Epoch 5/40
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.7844 - accuracy: 0.7282 - val_loss: 0.8644 - val_accuracy: 0.7002
# Epoch 6/40
# 50000/50000 [==============================] - 9s 170us/sample - loss: 0.6611 - accuracy: 0.7690 - val_loss: 0.6830 - val_accuracy: 0.7650
# Epoch 7/40
# 50000/50000 [==============================] - 9s 178us/sample - loss: 0.6180 - accuracy: 0.7831 - val_loss: 0.6201 - val_accuracy: 0.7810
# Epoch 8/40
# 50000/50000 [==============================] - 9s 178us/sample - loss: 0.5877 - accuracy: 0.7912 - val_loss: 0.6012 - val_accuracy: 0.7890
# Epoch 9/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.5715 - accuracy: 0.7976 - val_loss: 0.6139 - val_accuracy: 0.7873
# Epoch 10/40
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.5578 - accuracy: 0.8027 - val_loss: 0.6007 - val_accuracy: 0.7901
# Epoch 11/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.5307 - accuracy: 0.8113 - val_loss: 0.5780 - val_accuracy: 0.7957
# Epoch 12/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.5175 - accuracy: 0.8172 - val_loss: 0.5772 - val_accuracy: 0.7973
# Epoch 13/40
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.5138 - accuracy: 0.8184 - val_loss: 0.5749 - val_accuracy: 0.7971
# Epoch 14/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.5063 - accuracy: 0.8214 - val_loss: 0.5718 - val_accuracy: 0.8000
# Epoch 15/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.5048 - accuracy: 0.8216 - val_loss: 0.5669 - val_accuracy: 0.7999
# Epoch 16/40
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4959 - accuracy: 0.8254 - val_loss: 0.5694 - val_accuracy: 0.7996
# Epoch 17/40
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.4929 - accuracy: 0.8245 - val_loss: 0.5698 - val_accuracy: 0.7994
# Epoch 18/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.4904 - accuracy: 0.8240 - val_loss: 0.5674 - val_accuracy: 0.7985
# Epoch 19/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4904 - accuracy: 0.8271 - val_loss: 0.5683 - val_accuracy: 0.7993
# Epoch 20/40
# 50000/50000 [==============================] - 9s 181us/sample - loss: 0.4855 - accuracy: 0.8279 - val_loss: 0.5656 - val_accuracy: 0.8005
# Epoch 21/40
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.4863 - accuracy: 0.8278 - val_loss: 0.5659 - val_accuracy: 0.7984
# Epoch 22/40
# 50000/50000 [==============================] - 9s 189us/sample - loss: 0.4848 - accuracy: 0.8276 - val_loss: 0.5670 - val_accuracy: 0.7983
# Epoch 23/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.4818 - accuracy: 0.8287 - val_loss: 0.5650 - val_accuracy: 0.7999
# Epoch 24/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4799 - accuracy: 0.8292 - val_loss: 0.5667 - val_accuracy: 0.7990
# Epoch 25/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4849 - accuracy: 0.8280 - val_loss: 0.5663 - val_accuracy: 0.7983
# Epoch 26/40
# 50000/50000 [==============================] - 9s 181us/sample - loss: 0.4825 - accuracy: 0.8284 - val_loss: 0.5653 - val_accuracy: 0.7983
# Epoch 27/40
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.4848 - accuracy: 0.8290 - val_loss: 0.5661 - val_accuracy: 0.7987
# Epoch 28/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.4830 - accuracy: 0.8298 - val_loss: 0.5655 - val_accuracy: 0.7982
# Epoch 29/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4807 - accuracy: 0.8285 - val_loss: 0.5652 - val_accuracy: 0.8001
# Epoch 30/40
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4800 - accuracy: 0.8301 - val_loss: 0.5654 - val_accuracy: 0.7993
# Epoch 31/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4838 - accuracy: 0.8283 - val_loss: 0.5648 - val_accuracy: 0.7988
# Epoch 32/40
# 50000/50000 [==============================] - 9s 181us/sample - loss: 0.4817 - accuracy: 0.8295 - val_loss: 0.5663 - val_accuracy: 0.7992
# Epoch 33/40
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.4824 - accuracy: 0.8293 - val_loss: 0.5670 - val_accuracy: 0.7994
# Epoch 34/40
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.4838 - accuracy: 0.8286 - val_loss: 0.5662 - val_accuracy: 0.7985
# Epoch 35/40
# 50000/50000 [==============================] - 9s 179us/sample - loss: 0.4798 - accuracy: 0.8291 - val_loss: 0.5662 - val_accuracy: 0.7986
# Epoch 36/40
# 50000/50000 [==============================] - 9s 182us/sample - loss: 0.4880 - accuracy: 0.8273 - val_loss: 0.5676 - val_accuracy: 0.7987
# Epoch 37/40
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4791 - accuracy: 0.8296 - val_loss: 0.5653 - val_accuracy: 0.8000
# Epoch 38/40
# 50000/50000 [==============================] - 9s 184us/sample - loss: 0.4820 - accuracy: 0.8285 - val_loss: 0.5658 - val_accuracy: 0.7983
# Epoch 39/40
# 50000/50000 [==============================] - 10s 193us/sample - loss: 0.4865 - accuracy: 0.8257 - val_loss: 0.5665 - val_accuracy: 0.7991
# Epoch 40/40
# 50000/50000 [==============================] - 9s 186us/sample - loss: 0.4846 - accuracy: 0.8267 - val_loss: 0.5655 - val_accuracy: 0.7991

# %% [markdown]
# ### Predicting on the trained model and evaluating it

# %% [markdown]
# **Predicting**

# %%
predictions = model.predict(X_test, batch_size = 64)

# %% [markdown]
# **Classification Report**

# %%
cr = classification_report(y_test.argmax(axis = 1), predictions.argmax(axis =1),
                           target_names = labelNames)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.80      0.82      1000
#   automobile       0.92      0.89      0.90      1000
#         bird       0.75      0.67      0.71      1000
#          cat       0.64      0.59      0.61      1000
#         deer       0.73      0.79      0.76      1000
#          dog       0.71      0.72      0.71      1000
#         frog       0.80      0.89      0.84      1000
#        horse       0.84      0.84      0.84      1000
#         ship       0.90      0.90      0.90      1000
#        truck       0.85      0.90      0.87      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000

# %% [markdown]
# **Visualizing the metrics results**

# %%
plt.style.use("ggplot")
plt.figure(figsize=(20,20))
plt.plot(np.arange(0, 40), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 40), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 40), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 40), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on CIFAR10 with Learning rate decay by a factor of 0.25")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.axis('on')
plt.legend()
plt.show()

# %% [markdown]
# **Creating the step function decay for a factor $F=0.5$.**

# %%
def step_decay(epoch, lr):
    
    init_alpha = 0.01 # initial learning rate
    factor = 0.5
    dropEvery = 5 # step size
    
    if epoch == 1:
        lr = init_alpha
    elif   epoch%5 == 0:
        lr = init_alpha * (factor ** np.floor((1 + epoch) / dropEvery))
    else:
        lr = lr
    return lr

# %% [markdown]
# **Creating the callbacks and the model**

# %%
callbacks = [LearningRateScheduler(step_decay)]

# %%
opt = SGD(momentum=0.9, nesterov=True) # regularization
model = MiniVGG.build(32, 32, 3, 10) # w, h, depth, classes
model.compile(loss = "categorical_crossentropy",
              optimizer = opt,
              metrics = ["accuracy"]) # Compiling the model

# %% [markdown]
# **Training the model with $40$ epochs with a factor $F = 0.5$ in the step function.**

# %%
H = model.fit(X_train, y_train, validation_data = (X_test, y_test),
              batch_size = 64, epochs = 40, callbacks=callbacks, verbose = 1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 11s 223us/sample - loss: 1.6838 - accuracy: 0.4389 - val_loss: 1.4631 - val_accuracy: 0.5278
# Epoch 2/40
# 50000/50000 [==============================] - 9s 174us/sample - loss: 1.2131 - accuracy: 0.5812 - val_loss: 0.9355 - val_accuracy: 0.6695
# Epoch 3/40
# 50000/50000 [==============================] - 9s 171us/sample - loss: 1.0015 - accuracy: 0.6523 - val_loss: 1.0728 - val_accuracy: 0.6433
# Epoch 4/40
# 50000/50000 [==============================] - 8s 167us/sample - loss: 0.8893 - accuracy: 0.6905 - val_loss: 0.8513 - val_accuracy: 0.7072
# Epoch 5/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.8044 - accuracy: 0.7186 - val_loss: 0.7680 - val_accuracy: 0.7341
# Epoch 6/40
# 50000/50000 [==============================] - 9s 172us/sample - loss: 0.6977 - accuracy: 0.7549 - val_loss: 0.6775 - val_accuracy: 0.7613
# Epoch 7/40
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.6382 - accuracy: 0.7740 - val_loss: 0.6440 - val_accuracy: 0.7779
# Epoch 8/40
# 50000/50000 [==============================] - 8s 169us/sample - loss: 0.6118 - accuracy: 0.7837 - val_loss: 0.7191 - val_accuracy: 0.7557
# Epoch 9/40
# 50000/50000 [==============================] - 8s 170us/sample - loss: 0.5847 - accuracy: 0.7933 - val_loss: 0.6212 - val_accuracy: 0.7847
# Epoch 10/40
# 50000/50000 [==============================] - 8s 170us/sample - loss: 0.5554 - accuracy: 0.8033 - val_loss: 0.6105 - val_accuracy: 0.7931
# Epoch 11/40
# 50000/50000 [==============================] - 9s 170us/sample - loss: 0.5141 - accuracy: 0.8186 - val_loss: 0.5756 - val_accuracy: 0.8067
# Epoch 12/40
# 50000/50000 [==============================] - 8s 170us/sample - loss: 0.4935 - accuracy: 0.8242 - val_loss: 0.5799 - val_accuracy: 0.8052
# Epoch 13/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.4729 - accuracy: 0.8316 - val_loss: 0.5810 - val_accuracy: 0.8077
# Epoch 14/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.4563 - accuracy: 0.8380 - val_loss: 0.5629 - val_accuracy: 0.8103
# Epoch 15/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.4472 - accuracy: 0.8406 - val_loss: 0.5615 - val_accuracy: 0.8105
# Epoch 16/40
# 50000/50000 [==============================] - 9s 173us/sample - loss: 0.4244 - accuracy: 0.8502 - val_loss: 0.5534 - val_accuracy: 0.8129
# Epoch 17/40
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.4117 - accuracy: 0.8526 - val_loss: 0.5567 - val_accuracy: 0.8128
# Epoch 18/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.4084 - accuracy: 0.8560 - val_loss: 0.5467 - val_accuracy: 0.8192
# Epoch 19/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.3977 - accuracy: 0.8584 - val_loss: 0.5578 - val_accuracy: 0.8146
# Epoch 20/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3955 - accuracy: 0.8597 - val_loss: 0.5476 - val_accuracy: 0.8203
# Epoch 21/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.3792 - accuracy: 0.8640 - val_loss: 0.5531 - val_accuracy: 0.8179
# Epoch 22/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3758 - accuracy: 0.8668 - val_loss: 0.5464 - val_accuracy: 0.8176
# Epoch 23/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.3720 - accuracy: 0.8670 - val_loss: 0.5443 - val_accuracy: 0.8179
# Epoch 24/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.3743 - accuracy: 0.8666 - val_loss: 0.5413 - val_accuracy: 0.8191
# Epoch 25/40
# 50000/50000 [==============================] - 9s 178us/sample - loss: 0.3643 - accuracy: 0.8705 - val_loss: 0.5463 - val_accuracy: 0.8183
# Epoch 26/40
# 50000/50000 [==============================] - 9s 181us/sample - loss: 0.3577 - accuracy: 0.8730 - val_loss: 0.5381 - val_accuracy: 0.8214
# Epoch 27/40
# 50000/50000 [==============================] - 9s 178us/sample - loss: 0.3568 - accuracy: 0.8724 - val_loss: 0.5366 - val_accuracy: 0.8237
# Epoch 28/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3517 - accuracy: 0.8748 - val_loss: 0.5399 - val_accuracy: 0.8216
# Epoch 29/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3506 - accuracy: 0.8756 - val_loss: 0.5394 - val_accuracy: 0.8215
# Epoch 30/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.3502 - accuracy: 0.8756 - val_loss: 0.5402 - val_accuracy: 0.8208
# Epoch 31/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3471 - accuracy: 0.8770 - val_loss: 0.5369 - val_accuracy: 0.8227
# Epoch 32/40
# 50000/50000 [==============================] - 9s 176us/sample - loss: 0.3451 - accuracy: 0.8766 - val_loss: 0.5369 - val_accuracy: 0.8222
# Epoch 33/40
# 50000/50000 [==============================] - 9s 178us/sample - loss: 0.3430 - accuracy: 0.8787 - val_loss: 0.5381 - val_accuracy: 0.8215
# Epoch 34/40
# 50000/50000 [==============================] - 9s 173us/sample - loss: 0.3477 - accuracy: 0.8760 - val_loss: 0.5388 - val_accuracy: 0.8226
# Epoch 35/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3393 - accuracy: 0.8790 - val_loss: 0.5374 - val_accuracy: 0.8247
# Epoch 36/40
# 50000/50000 [==============================] - 9s 174us/sample - loss: 0.3418 - accuracy: 0.8769 - val_loss: 0.5367 - val_accuracy: 0.8235
# Epoch 37/40
# 50000/50000 [==============================] - 9s 183us/sample - loss: 0.3412 - accuracy: 0.8785 - val_loss: 0.5367 - val_accuracy: 0.8242
# Epoch 38/40
# 50000/50000 [==============================] - 9s 177us/sample - loss: 0.3384 - accuracy: 0.8807 - val_loss: 0.5365 - val_accuracy: 0.8250
# Epoch 39/40
# 50000/50000 [==============================] - 9s 180us/sample - loss: 0.3386 - accuracy: 0.8798 - val_loss: 0.5368 - val_accuracy: 0.8244
# Epoch 40/40
# 50000/50000 [==============================] - 9s 175us/sample - loss: 0.3404 - accuracy: 0.8792 - val_loss: 0.5376 - val_accuracy: 0.8246

# %% [markdown]
# ### Predicting on the trained model and evaluating it

# %% [markdown]
# **Predicting**

# %%
predictions = model.predict(X_test, batch_size = 64)

# %% [markdown]
# **Classification Report**

# %%
cr = classification_report(y_test.argmax(axis = 1), predictions.argmax(axis =1),
                           target_names = labelNames)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.82      0.84      1000
#   automobile       0.92      0.91      0.91      1000
#         bird       0.80      0.71      0.75      1000
#          cat       0.67      0.67      0.67      1000
#         deer       0.77      0.83      0.80      1000
#          dog       0.73      0.75      0.74      1000
#         frog       0.84      0.88      0.86      1000
#        horse       0.88      0.87      0.88      1000
#         ship       0.91      0.91      0.91      1000
#        truck       0.88      0.90      0.89      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000

# %% [markdown]
# **Visualizing the metrics results**

# %%
plt.style.use("ggplot")
plt.figure(figsize=(20,20))
plt.plot(np.arange(0, 40), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 40), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 40), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 40), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on CIFAR10 with Learning rate decay by a factor of 0.5")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.axis('on')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# As we can see, the results in this example are not so far from the last [example](https://github.com/IgorMeloS/Computer-Vision-Training/blob/main/ComputerVision%20Module/Pratical%20Examples/5%20-%20MiniVGG%20on%20CIFAR10/minivgg_cifar10.ipynb). For the first model, we've considered a factor of $0.25$ for the piecewise function. The accuracy on the test set was $79\%$ and $82\%$ for the training test. This indicates that our model is out of over-fit. If we look for the loss function, there's a little difference between the curves, indicating that our model can be in over-fitting. There is also another factor, for the both metrics, accuracy and loss, the curves have stagnated after $15$ epochs.
#
# The results for the model with a factor of $0.5$ was better, if we consider the absolute value of the accuracy on the test set. But the gap between the curves demonstrates that our model can be in over-fitting situation, as in the previous example.
#
# So, the Learning Rate Scheduler can improve our results, as we have seen for the model with the factor of $0.25$. We must keep in mind that our data is not enough large and, there exist other techniques to improve these results and avoid the over-fit. In general, Learning Rate Scheduler is a good step to think about.
