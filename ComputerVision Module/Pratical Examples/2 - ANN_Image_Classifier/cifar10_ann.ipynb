# %% [markdown]
# # CIFAR10 dataset on the Artificial Neural Network
#
# In this notebook, we are going to train the CIFAR10 dataset on the Artificial Neural Network (ANN). We consider the ANN contained in the compvis module, but also, we build a model with TensorFlow. Finally, we compare the performance and results from both models.

# %% [markdown]
# ## Importing Libraries

# %%
from compvis.ann import ANN # compvis ANN
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading the CIFAR10 dataset from Scikit-Learn

# %%
((X_train, y_train), (X_test, y_test)) = cifar10.load_data()

# %% [markdown]
# ## Splitting the dataset into training and test set

# %%
X_train = X_train.astype("float")/255. # Normalizing
X_test = X_test.astype("float")/255.
X_train = X_train.reshape((X_train.shape[0], 3072)) #reshaping
X_test = X_test.reshape((X_test.shape[0], 3072))

# %% [markdown]
# **Label binarize to transform labels into numbers**

# %%
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
labelNames = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog",
              "horse", "ship", "truck"]

# %% [markdown]
# ## Creating the model

# %%
ann = ANN([X_train.shape[1], 32, 16, 10], alpha=0.01)

# %%
print(ann)
# Out:
# NeuralNetwork: 3072-32-16-10

# %% [markdown]
# ### Training the model

# %%
ann.fit(X_train, y_train, epochs = 100, verbose=10)
# Out:
# [INFO] Training the model
# epoch 1, loss: 0.4363448
# epoch 10, loss: 0.3664302
# epoch 20, loss: 0.3429545
# epoch 30, loss: 0.3325267
# epoch 40, loss: 0.3233836
# epoch 50, loss: 0.3187959
# epoch 60, loss: 0.3161726
# epoch 70, loss: 0.3119917
# epoch 80, loss: 0.3097262
# epoch 90, loss: 0.3075226
# epoch 100, loss: 0.3073123

# %% [markdown]
# **Predicting on the model**

# %%
predictions = ann.predict(X_test)

# %% [markdown]
# **Evaluating the model**

# %%
cr = classification_report(y_test.argmax(axis=1), predictions.argmax(axis=1),
                           target_names = labelNames)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.53      0.49      0.51      1000
#   automobile       0.53      0.55      0.54      1000
#         bird       0.35      0.27      0.31      1000
#          cat       0.27      0.37      0.32      1000
#         deer       0.36      0.46      0.40      1000
#          dog       0.36      0.28      0.32      1000
#         frog       0.43      0.51      0.46      1000
#        horse       0.58      0.39      0.46      1000
#         ship       0.60      0.59      0.60      1000
#        truck       0.48      0.49      0.49      1000
#
#     accuracy                           0.44     10000
#    macro avg       0.45      0.44      0.44     10000
# weighted avg       0.45      0.44      0.44     10000

# %% [markdown]
# ## TensorFlow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ### Creating the Sequential model 3072-1024-512-10

# %%
model = Sequential() # To create the network
model.add(Dense(1024, input_shape=(3072, ), activation="relu")) # To connect the input layer with the first hidden layer
model.add(Dense(512, activation="relu")) # To connect the first hidden layer with the second hidden layer
model.add(Dense(10, activation="softmax")) # To connect the second hidden layer with the output layer

# %% [markdown]
# ### Training the model

# %%
sgd = SGD(0.01) # to optimizer the model 

model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"]) # compiling the model

# %%
# Fitting
H = model.fit(X_train, y_train, validation_data=(X_test, y_test),
              epochs = 100, batch_size=32)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 5s 103us/sample - loss: 1.8393 - accuracy: 0.3468 - val_loss: 1.7480 - val_accuracy: 0.3704
# Epoch 2/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.6546 - accuracy: 0.4174 - val_loss: 1.6704 - val_accuracy: 0.4036
# Epoch 3/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 1.5722 - accuracy: 0.4440 - val_loss: 1.5737 - val_accuracy: 0.4357
# Epoch 4/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.5156 - accuracy: 0.4655 - val_loss: 1.5321 - val_accuracy: 0.4551
# Epoch 5/100
# 50000/50000 [==============================] - 5s 97us/sample - loss: 1.4669 - accuracy: 0.4813 - val_loss: 1.4755 - val_accuracy: 0.4724
# Epoch 6/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 1.4273 - accuracy: 0.4946 - val_loss: 1.5478 - val_accuracy: 0.4303
# Epoch 7/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.3881 - accuracy: 0.5102 - val_loss: 1.4051 - val_accuracy: 0.4969
# Epoch 8/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 1.3559 - accuracy: 0.5214 - val_loss: 1.3992 - val_accuracy: 0.5006
# Epoch 9/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.3258 - accuracy: 0.5332 - val_loss: 1.4152 - val_accuracy: 0.4966
# Epoch 10/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.2974 - accuracy: 0.5429 - val_loss: 1.3655 - val_accuracy: 0.5153
# Epoch 11/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.2711 - accuracy: 0.5515 - val_loss: 1.4039 - val_accuracy: 0.4985
# Epoch 12/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.2464 - accuracy: 0.5612 - val_loss: 1.5571 - val_accuracy: 0.4540
# Epoch 13/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 1.2217 - accuracy: 0.5683 - val_loss: 1.3721 - val_accuracy: 0.5115
# Epoch 14/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.1953 - accuracy: 0.5785 - val_loss: 1.4379 - val_accuracy: 0.4904
# Epoch 15/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.1758 - accuracy: 0.5853 - val_loss: 1.5058 - val_accuracy: 0.4718
# Epoch 16/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.1514 - accuracy: 0.5975 - val_loss: 1.3110 - val_accuracy: 0.5375
# Epoch 17/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.1290 - accuracy: 0.6034 - val_loss: 1.3208 - val_accuracy: 0.5310
# Epoch 18/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.1066 - accuracy: 0.6126 - val_loss: 1.3670 - val_accuracy: 0.5238
# Epoch 19/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.0852 - accuracy: 0.6214 - val_loss: 1.3340 - val_accuracy: 0.5280
# Epoch 20/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.0632 - accuracy: 0.6281 - val_loss: 1.4060 - val_accuracy: 0.5033
# Epoch 21/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.0422 - accuracy: 0.6347 - val_loss: 1.2957 - val_accuracy: 0.5425
# Epoch 22/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.0214 - accuracy: 0.6414 - val_loss: 1.3440 - val_accuracy: 0.5292
# Epoch 23/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 1.0013 - accuracy: 0.6496 - val_loss: 1.4519 - val_accuracy: 0.4947
# Epoch 24/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.9800 - accuracy: 0.6568 - val_loss: 1.4143 - val_accuracy: 0.5145
# Epoch 25/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.9583 - accuracy: 0.6657 - val_loss: 1.2987 - val_accuracy: 0.5466
# Epoch 26/100
# 50000/50000 [==============================] - 5s 91us/sample - loss: 0.9408 - accuracy: 0.6712 - val_loss: 1.2986 - val_accuracy: 0.5452
# Epoch 27/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.9159 - accuracy: 0.6829 - val_loss: 1.3740 - val_accuracy: 0.5292
# Epoch 28/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.8941 - accuracy: 0.6864 - val_loss: 1.3422 - val_accuracy: 0.5373
# Epoch 29/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.8741 - accuracy: 0.6962 - val_loss: 1.3597 - val_accuracy: 0.5400
# Epoch 30/100
# 50000/50000 [==============================] - 5s 92us/sample - loss: 0.8551 - accuracy: 0.7020 - val_loss: 1.3477 - val_accuracy: 0.5375
# Epoch 31/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.8330 - accuracy: 0.7083 - val_loss: 1.3521 - val_accuracy: 0.5403
# Epoch 32/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.8144 - accuracy: 0.7151 - val_loss: 1.5612 - val_accuracy: 0.4995
# Epoch 33/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.7910 - accuracy: 0.7268 - val_loss: 1.4441 - val_accuracy: 0.5246
# Epoch 34/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.7708 - accuracy: 0.7331 - val_loss: 1.3072 - val_accuracy: 0.5614
# Epoch 35/100
# 50000/50000 [==============================] - 4s 85us/sample - loss: 0.7522 - accuracy: 0.7408 - val_loss: 1.3464 - val_accuracy: 0.5508
# Epoch 36/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.7363 - accuracy: 0.7451 - val_loss: 1.3191 - val_accuracy: 0.5618
# Epoch 37/100
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.7101 - accuracy: 0.7558 - val_loss: 1.3640 - val_accuracy: 0.5498
# Epoch 38/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.6908 - accuracy: 0.7614 - val_loss: 1.4266 - val_accuracy: 0.5438
# Epoch 39/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.6716 - accuracy: 0.7696 - val_loss: 1.3750 - val_accuracy: 0.5490
# Epoch 40/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.6537 - accuracy: 0.7760 - val_loss: 1.4322 - val_accuracy: 0.5389
# Epoch 41/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.6303 - accuracy: 0.7826 - val_loss: 1.4840 - val_accuracy: 0.5345
# Epoch 42/100
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.6093 - accuracy: 0.7942 - val_loss: 1.4563 - val_accuracy: 0.5410
# Epoch 43/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.5955 - accuracy: 0.7967 - val_loss: 1.5264 - val_accuracy: 0.5371
# Epoch 44/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.5747 - accuracy: 0.8036 - val_loss: 1.4770 - val_accuracy: 0.5494
# Epoch 45/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.5520 - accuracy: 0.8125 - val_loss: 1.4368 - val_accuracy: 0.5598
# Epoch 46/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.5361 - accuracy: 0.8179 - val_loss: 1.4858 - val_accuracy: 0.5497
# Epoch 47/100
# 50000/50000 [==============================] - 5s 91us/sample - loss: 0.5143 - accuracy: 0.8266 - val_loss: 1.4653 - val_accuracy: 0.5568
# Epoch 48/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.4985 - accuracy: 0.8324 - val_loss: 1.5134 - val_accuracy: 0.5562
# Epoch 49/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.4832 - accuracy: 0.8380 - val_loss: 1.6198 - val_accuracy: 0.5329
# Epoch 50/100
# 50000/50000 [==============================] - 4s 85us/sample - loss: 0.4626 - accuracy: 0.8473 - val_loss: 1.6172 - val_accuracy: 0.5317
# Epoch 51/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.4458 - accuracy: 0.8522 - val_loss: 1.6850 - val_accuracy: 0.5256
# Epoch 52/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.4283 - accuracy: 0.8590 - val_loss: 1.7060 - val_accuracy: 0.5276
# Epoch 53/100
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.4121 - accuracy: 0.8629 - val_loss: 1.5485 - val_accuracy: 0.5552
# Epoch 54/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.3962 - accuracy: 0.8700 - val_loss: 1.6123 - val_accuracy: 0.5455
# Epoch 55/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.3762 - accuracy: 0.8775 - val_loss: 1.6636 - val_accuracy: 0.5437
# Epoch 56/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.3668 - accuracy: 0.8803 - val_loss: 1.6078 - val_accuracy: 0.5609
# Epoch 57/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.3461 - accuracy: 0.8879 - val_loss: 1.7259 - val_accuracy: 0.5403
# Epoch 58/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.3291 - accuracy: 0.8947 - val_loss: 1.8384 - val_accuracy: 0.5224
# Epoch 59/100
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.3198 - accuracy: 0.8985 - val_loss: 1.6009 - val_accuracy: 0.5632
# Epoch 60/100
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.3058 - accuracy: 0.9030 - val_loss: 1.6413 - val_accuracy: 0.5661
# Epoch 61/100
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.2913 - accuracy: 0.9088 - val_loss: 1.7325 - val_accuracy: 0.5534
# Epoch 62/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.2787 - accuracy: 0.9132 - val_loss: 1.9395 - val_accuracy: 0.5199
# Epoch 63/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.2659 - accuracy: 0.9183 - val_loss: 1.7868 - val_accuracy: 0.5471
# Epoch 64/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.2541 - accuracy: 0.9207 - val_loss: 1.7639 - val_accuracy: 0.5555
# Epoch 65/100
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.2388 - accuracy: 0.9278 - val_loss: 1.7978 - val_accuracy: 0.5555
# Epoch 66/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.2260 - accuracy: 0.9322 - val_loss: 1.7925 - val_accuracy: 0.5644
# Epoch 67/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.2173 - accuracy: 0.9355 - val_loss: 1.8926 - val_accuracy: 0.5460
# Epoch 68/100
# 50000/50000 [==============================] - 5s 94us/sample - loss: 0.2113 - accuracy: 0.9373 - val_loss: 1.8211 - val_accuracy: 0.5557
# Epoch 69/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.1953 - accuracy: 0.9441 - val_loss: 1.9997 - val_accuracy: 0.5360
# Epoch 70/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.1842 - accuracy: 0.9474 - val_loss: 1.8792 - val_accuracy: 0.5591
# Epoch 71/100
# 50000/50000 [==============================] - 5s 99us/sample - loss: 0.1805 - accuracy: 0.9486 - val_loss: 2.0009 - val_accuracy: 0.5420
# Epoch 72/100
# 50000/50000 [==============================] - 5s 92us/sample - loss: 0.1659 - accuracy: 0.9536 - val_loss: 1.9562 - val_accuracy: 0.5468
# Epoch 73/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.1579 - accuracy: 0.9572 - val_loss: 2.0941 - val_accuracy: 0.5410
# Epoch 74/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.1482 - accuracy: 0.9603 - val_loss: 1.9571 - val_accuracy: 0.5597
# Epoch 75/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.1466 - accuracy: 0.9601 - val_loss: 1.9878 - val_accuracy: 0.5570
# Epoch 76/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.1324 - accuracy: 0.9657 - val_loss: 2.0809 - val_accuracy: 0.5412
# Epoch 77/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.1258 - accuracy: 0.9667 - val_loss: 2.0026 - val_accuracy: 0.5558
# Epoch 78/100
# 50000/50000 [==============================] - 5s 91us/sample - loss: 0.1185 - accuracy: 0.9707 - val_loss: 1.9517 - val_accuracy: 0.5684
# Epoch 79/100
# 50000/50000 [==============================] - 5s 91us/sample - loss: 0.1061 - accuracy: 0.9745 - val_loss: 2.1322 - val_accuracy: 0.5506
# Epoch 80/100
# 50000/50000 [==============================] - 4s 85us/sample - loss: 0.1041 - accuracy: 0.9746 - val_loss: 2.1674 - val_accuracy: 0.5501
# Epoch 81/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.1002 - accuracy: 0.9756 - val_loss: 2.1484 - val_accuracy: 0.5472
# Epoch 82/100
# 50000/50000 [==============================] - 5s 92us/sample - loss: 0.0892 - accuracy: 0.9799 - val_loss: 2.0130 - val_accuracy: 0.5709
# Epoch 83/100
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.0832 - accuracy: 0.9814 - val_loss: 2.0620 - val_accuracy: 0.5652
# Epoch 84/100
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.0786 - accuracy: 0.9829 - val_loss: 2.1295 - val_accuracy: 0.5601
# Epoch 85/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0755 - accuracy: 0.9838 - val_loss: 2.2826 - val_accuracy: 0.5401
# Epoch 86/100
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.0697 - accuracy: 0.9863 - val_loss: 2.1126 - val_accuracy: 0.5686
# Epoch 87/100
# 50000/50000 [==============================] - 4s 89us/sample - loss: 0.0669 - accuracy: 0.9863 - val_loss: 2.1795 - val_accuracy: 0.5588
# Epoch 88/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.0638 - accuracy: 0.9872 - val_loss: 2.1499 - val_accuracy: 0.5616
# Epoch 89/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.0606 - accuracy: 0.9881 - val_loss: 2.3105 - val_accuracy: 0.5525
# Epoch 90/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0527 - accuracy: 0.9909 - val_loss: 2.1945 - val_accuracy: 0.5645
# Epoch 91/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0479 - accuracy: 0.9919 - val_loss: 2.2057 - val_accuracy: 0.5626
# Epoch 92/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.0425 - accuracy: 0.9936 - val_loss: 2.1886 - val_accuracy: 0.5681
# Epoch 93/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0429 - accuracy: 0.9934 - val_loss: 2.2587 - val_accuracy: 0.5621
# Epoch 94/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0398 - accuracy: 0.9942 - val_loss: 2.2129 - val_accuracy: 0.5683
# Epoch 95/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0353 - accuracy: 0.9956 - val_loss: 2.2690 - val_accuracy: 0.5633
# Epoch 96/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.0333 - accuracy: 0.9957 - val_loss: 2.2310 - val_accuracy: 0.5722
# Epoch 97/100
# 50000/50000 [==============================] - 4s 85us/sample - loss: 0.0311 - accuracy: 0.9963 - val_loss: 2.2356 - val_accuracy: 0.5730
# Epoch 98/100
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.0306 - accuracy: 0.9962 - val_loss: 2.2652 - val_accuracy: 0.5694
# Epoch 99/100
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.0275 - accuracy: 0.9969 - val_loss: 2.2548 - val_accuracy: 0.5718
# Epoch 100/100
# 50000/50000 [==============================] - 5s 90us/sample - loss: 0.0267 - accuracy: 0.9970 - val_loss: 2.2867 - val_accuracy: 0.5677

# %% [markdown]
# ### Predicting and evaluation

# %%
preds = model.predict(X_test, batch_size=32) # to predict

# %%
cr = classification_report(y_test.argmax(axis=1), preds.argmax(axis=1),
                           target_names = labelNames)

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.66      0.64      0.65      1000
#   automobile       0.63      0.73      0.68      1000
#         bird       0.43      0.52      0.47      1000
#          cat       0.40      0.40      0.40      1000
#         deer       0.50      0.47      0.49      1000
#          dog       0.47      0.45      0.46      1000
#         frog       0.64      0.61      0.63      1000
#        horse       0.64      0.60      0.62      1000
#         ship       0.70      0.69      0.69      1000
#        truck       0.63      0.57      0.60      1000
#
#     accuracy                           0.57     10000
#    macro avg       0.57      0.57      0.57     10000
# weighted avg       0.57      0.57      0.57     10000

# %% [markdown]
# ### Visualizing the metrics

# %%
plt.style.use("ggplot")
plt.figure(figsize=(20,20))
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 100), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 100), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Results
#
# The ANN model provided by our module, does not show someones result and spend much time to run. On other hand, the model from TensorFlow turns quickly due to the CUDA and the results are more accurate due to a better regularization. So, the ANN model presented in this module, is merely pedagogical. We’ll always choose library as TensorFLow, Keras and PyTorch.
#
# About the accuracy from the TensorFlow model, we can see a value of $57 \%$ on the test set. During the training, the train accuracy and loss show smooth curves, but on the validation set, the result are far from the training results, we are in a case of over-fitting, But this will be covered in more detail later.
